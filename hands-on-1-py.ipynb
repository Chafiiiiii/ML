# %% [markdown]
# ##  Hands On: Data Import and Manipulation

# %% [markdown]
# ## 1. Introduction to Python for Machine Learning

# %% [markdown]
# #### a) Create an array of 10 random integers between 1 and 100, and then calculate the mean and standard deviation of the array.

# %%
import random
import math

# Generate an array of 10 random integers between 1 and 100
random_array = [random.randint(1, 100) for _ in range(10)]

# Calculate the mean
mean = sum(random_array) / len(random_array)

# Calculate the standard deviation
variance = sum((x - mean) ** 2 for x in random_array) / len(random_array)
std_deviation = math.sqrt(variance)

# Print the array, mean, and standard deviation
print("Array:", random_array)
print("Mean:", mean)
print("Standard Deviation:", std_deviation)
# Out:
# Array: [79, 1, 36, 3, 84, 99, 100, 59, 18, 91]
# Mean: 57.0
# Standard Deviation: 37.416573867739416

# %% [markdown]
# #### b) Create a 2-dimensional array of 3 rows and 4 columns with random integer values. Then, calculate the sum of each row and column.

# %%
# Create a 2-dimensional array of 3 rows and 4 columns with random integer values
array = [[random.randint(1, 100) for _ in range(4)] for _ in range(3)]

# Calculate the sum of each row
row_sums = [sum(row) for row in array]

# Calculate the sum of each column
column_sums = [sum(col) for col in zip(*array)]

# Print the array, sum of each row, and sum of each column
print("Array:")
for row in array:
    print(row)
print("Sum of each row:", row_sums)
print("Sum of each column:", column_sums)
# Out:
# Array:
# [34, 3, 98, 95]
# [99, 19, 82, 1]
# [69, 89, 38, 6]
# Sum of each row: [230, 201, 202]
# Sum of each column: [202, 111, 218, 102]

# %% [markdown]
# #### c) Create a DataFrame with 3 columns: "Name", "Age", and "City". Add at least 5 rows of data to the DataFrame. Then, filter the DataFrame to only include rows where the person's age is greater than or equal to 30.

# %%
#Create a Dataframe with 3 columns:"Name","Age"and "City" 
#Add at least 5 rows of data to the Dataframe.
df ={
     "Name":["JUAN","PABLO","ANDRES","DANIEL","PEDRO"],
     "Age":[12,22,43,55,27],
     "City":["QUITO","AMBATO","LATACUNGA","GUAYAQUIL","MANTA"]
 }
new_data=pd.DataFrame(df)
new_data
# Out:
#      Name  Age       City
# 0    JUAN   12      QUITO
# 1   PABLO   22     AMBATO
# 2  ANDRES   43  LATACUNGA
# 3  DANIEL   55  GUAYAQUIL
# 4   PEDRO   27      MANTA

# %%
#. Then, filter the DataFrame to only include rows where the person's age is greater than
# or equal to 30.

df_filtrado=new_data[new_data["Age"]>=30]
df_filtrado
# Out:
#      Name  Age       City
# 2  ANDRES   43  LATACUNGA
# 3  DANIEL   55  GUAYAQUIL

# %% [markdown]
# ##### d)Load a CSV file into a DataFrame and then calculate the mean, median, and mode of one of the columns in the DataFrame.

# %%
import pandas as pd 
df=pd.read_csv('/kaggle/input/datos/ServiceArea.csv')
# Calculate the mean of a column
column_mean = df['VersionNum'].mean()

# Calculate the median of a column
column_median = df['VersionNum'].median()

# Calculate the mode of a column
column_mode = df['VersionNum'].mode()

# Print the header of the DataFrame
print(df.head())

# Print the mean, median, and mode
print("Mean:", column_mean)
print("Median:", column_median)
print("Mode:", column_mode)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        PA     22444       HIOS           9
# 1          2014        PA     22444       HIOS           9
# 2          2014        PA     22444       HIOS           9
# 3          2014        PA     22444       HIOS           9
# 4          2014        PA     22444       HIOS           9
#
#             ImportDate  IssuerId2 StateCode2 ServiceAreaId  \
# 0  2014-01-21 08:29:49      22444         PA        PAS001
# 1  2014-01-21 08:29:49      22444         PA        PAS001
# 2  2014-01-21 08:29:49      22444         PA        PAS001
# 3  2014-01-21 08:29:49      22444         PA        PAS001
# 4  2014-01-21 08:29:49      22444         PA        PAS001
#
#          ServiceAreaName CoverEntireState   County PartialCounty ZipCodes  \
# 0  Geisinger Health Plan               No  42103.0            No      NaN
# 1  Geisinger Health Plan               No  42105.0            No      NaN
# ...

# %% [markdown]
# #### e) Create a scatter plot of random x and y values between 1 and 100.

# %%
#Library Import
import matplotlib.pyplot as plt
import random as rd

# %%
#Create the random arrays of length 50
x=[rd.randint(1,100) for _ in range(50)]
y=[rd.randint(1,100) for _ in range(50)]
#Plot the scatter given the random x and y arrays
plt.scatter(x,y)

# %% [markdown]
# #### f) Load a CSV file into a DataFrame and then create a line chart of one of the columns in the DataFrame.

# %%
#Library Import
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Csv Load into dataframe
df=pd.read_csv('/kaggle/input/datos/ServiceArea.csv')
#Plotting the Column BusinessYear of the dataframe
plt.plot(df['BusinessYear'])

# Add labels and title
plt.xlabel('Index')
plt.ylabel('BusinessYear')
plt.title('Line Chart of BusinessYear')

# Show the plot
plt.show()

# %% [markdown]
# # 3. Data Import

# %% [markdown]
# ### The Echocardiogram data set in the UCI Machine Learning repository contains information on a set of
# ### patients that suffered heart attacks at some point in the past.

# %% [markdown]
# ##### a)Download the Echocardiogram data set and import it to a data frame. Read the information on the
# ##### data set and find out how missing values are represented and make sure that they are properly
# ##### represented

# %%
#Library import
import pandas as pd

# %%
#First transform .data to Csv adding the delimiter to omit lines with incomplete parameters
df = pd.read_csv('/kaggle/input/Electrocardiograma/echocardiogram.data', delimiter=',', on_bad_lines='skip')

#show the dataframe 
print(df)
# Out:
#       11  0  71  0.1  0.260       9  4.600    14      1    1.1  name 1.2 0.2
# 0     19  0  72    0  0.380       6  4.100    14  1.700  0.588  name   1   0
# 1     16  0  55    0  0.260       4  3.420    14      1      1  name   1   0
# 2     57  0  60    0  0.253  12.062  4.603    16  1.450  0.788  name   1   0
# 3     19  1  57    0  0.160      22  5.750    18  2.250  0.571  name   1   0
# 4     26  0  68    0  0.260       5  4.310    12      1  0.857  name   1   0
# ..   ... ..  ..  ...    ...     ...    ...   ...    ...    ...   ...  ..  ..
# 125  7.5  1  64    0   0.24    12.9   4.72    12      1  0.857  name   ?   ?
# 126   41  0  64    0   0.28    5.40   5.47    11   1.10  0.714  name   ?   ?
# 127   36  0  69    0   0.20    7.00   5.05  14.5   1.21  0.857  name   ?   ?
# 128   22  0  57    0   0.14    16.1   4.36    15   1.36  0.786  name   ?   ?
# 129   20  0  62    0   0.15       0   4.51  15.5  1.409  0.786  name   ?   ?
#
# [130 rows x 13 columns]

# %%
#after a close look into the dataframe we can see 
#that  some values are represented by ?

# %%
#here we chande the character ? for a value that are representative for the column
columna_posicion = 2  
valor_especifico = 22
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 3 
valor_especifico = 1
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)

# %%
columna_posicion = 4  
valor_especifico = 0
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 5  
valor_especifico = 0.260
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 6  
valor_especifico = 4
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 7  
valor_especifico = 3.420
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 8  
valor_especifico = 14
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 9 
valor_especifico = 1
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 10  
valor_especifico = 1
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 11 
valor_especifico = 'name'
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)
columna_posicion = 12  
valor_especifico = 1
df.iloc[:, columna_posicion] = df.iloc[:, columna_posicion].replace('?', valor_especifico)

# %% [markdown]
# ##### b) Assign the attributes with meaningful names. You can look for this information on the same webpage.

# %%
df.columns = ['survival', 'still-alive', 'age-at-heart-attack', 'pericardial-effusion', 'fractional-shortening ',
              'epss', 'lvdd', 'wall-motion-score', 'wall-motion-index','mult','name','group', 'alive-at-1']

#Print df header
print(df.head())
# Out:
#   survival  still-alive age-at-heart-attack  pericardial-effusion  \
# 0       19            0                  72                     0
# 1       16            0                  55                     0
# 2       57            0                  60                     0
# 3       19            1                  57                     0
# 4       26            0                  68                     0
#
#   fractional-shortening     epss   lvdd wall-motion-score wall-motion-index  \
# 0                  0.380       6  4.100                14             1.700
# 1                  0.260       4  3.420                14                 1
# 2                  0.253  12.062  4.603                16             1.450
# 3                  0.160      22  5.750                18             2.250
# 4                  0.260       5  4.310                12                 1
#
#     mult  name group alive-at-1
# 0  0.588  name     1          0
# 1      1  name     1          0
# ...

# %% [markdown]
# #####  c) According to that same information, is there any redundant or irrelevant attribute that you can remove? Remove them.

# %%
# as we can see in the documentation the best option to delete are mult, name, group.

# %%
#dropping the columns that were explained before
df=df.drop('mult',axis=1)
df=df.drop('name',axis=1)
df=df.drop('group',axis=1)

# %%
print(df)
# Out:
#     survival  still-alive age-at-heart-attack  pericardial-effusion  \
# 0         19            0                  72                     0
# 1         16            0                  55                     0
# 2         57            0                  60                     0
# 3         19            1                  57                     0
# 4         26            0                  68                     0
# ..       ...          ...                 ...                   ...
# 125      7.5            1                  64                     0
# 126       41            0                  64                     0
# 127       36            0                  69                     0
# 128       22            0                  57                     0
# 129       20            0                  62                     0
#
#     fractional-shortening     epss   lvdd wall-motion-score wall-motion-index  \
# ...

# %% [markdown]
# ##### (d) Is there any data type change that you find useful? Perform it

# %%
#first we need to know what kind of data are we working with
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   survival                130 non-null    object
#  1   still-alive             130 non-null    int64
#  2   age-at-heart-attack     130 non-null    object
#  3   pericardial-effusion    130 non-null    int64
#  4   fractional-shortening   130 non-null    object
#  5   epss                    130 non-null    object
#  6   lvdd                    130 non-null    object
#  7   wall-motion-score       130 non-null    object
#  8   wall-motion-index       130 non-null    object
#  9   alive-at-1              130 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 10.3+ KB

# %%
#To work with all the data we need to change the type object into int or float 
df['survival'] = pd.to_numeric(df['survival'], errors='coerce').astype(float)
df['age-at-heart-attack'] = pd.to_numeric(df['age-at-heart-attack'], errors='coerce').astype(int)
df['fractional-shortening'] = pd.to_numeric(df['fractional-shortening'], errors='coerce').astype(float)
df['epss'] = pd.to_numeric(df['epss'], errors='coerce').astype(float)
df['lvdd'] = pd.to_numeric(df['lvdd'], errors='coerce').astype(float)
df['wall-motion-score'] = pd.to_numeric(df['wall-motion-score'], errors='coerce').astype(float)
df['wall-motion-index'] = pd.to_numeric(df['wall-motion-index'], errors='coerce').astype(float)
df['alive-at-1'] = pd.to_numeric(df['alive-at-1'], errors='coerce').astype(int)

# %%
#as we can see before the change in done in the whole dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   survival                129 non-null    float64
#  1   still-alive             130 non-null    int64
#  2   age-at-heart-attack     130 non-null    object
#  3   pericardial-effusion    130 non-null    int64
#  4   fractional-shortening   130 non-null    object
#  5   epss                    130 non-null    object
#  6   lvdd                    130 non-null    object
#  7   wall-motion-score       130 non-null    object
#  8   wall-motion-index       130 non-null    object
#  9   alive-at-1              130 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 10.3+ KB

# %%
#after the change were done 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   survival                129 non-null    float64
#  1   still-alive             130 non-null    int64
#  2   age-at-heart-attack     130 non-null    int64
#  3   pericardial-effusion    130 non-null    int64
#  4   fractional-shortening   130 non-null    object
#  5   epss                    130 non-null    float64
#  6   lvdd                    130 non-null    float64
#  7   wall-motion-score       130 non-null    float64
#  8   wall-motion-index       130 non-null    float64
#  9   alive-at-1              130 non-null    int64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 10.3+ KB

# %%
ff
